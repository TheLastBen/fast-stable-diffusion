# %% [markdown]
# # **Colab From https://github.com/TheLastBen/fast-stable-diffusion, if you have any issues, feel free to discuss them.**

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
#@markdown # Installing Relaxed mode
# %%capture
# %cd /content/gdrive/MyDrive
# !git clone https://github.com/sd-webui/stable-diffusion-webui
# %cd /content/
# !git clone https://github.com/TheLastBen/fast-stable-diffusion
# !rm -R /content/gdrive/MyDrive/stable-diffusion-webui/scripts/frontend
# !cp '/content/fast-stable-diffusion/Relaxed-mode/Relaxed.py' '/content/gdrive/MyDrive/stable-diffusion-webui/scripts'
# %cd /content/gdrive/MyDrive/stable-diffusion-webui/
# !mkdir -p cache/{huggingface,torch}
# %cd /content/
# !ln -s /content/gdrive/MyDrive/stable-diffusion-webui/cache/huggingface ../root/.cache/
# !ln -s /content/gdrive/MyDrive/stable-diffusion-webui/cache/torch ../root/.cache/

# %%
import os
import time
from IPython.display import clear_output

#@markdown # Model Download/Load
token = "" #@param {type:"string"}
Redownload_the_original_model = False #@param {type:"boolean"}
if Redownload_the_original_model:
  # %cd /content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1
  # !wget -q -O model.ckpt https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/precompiled/attention.py
  # !mv /content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/model.ckpt /content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/trashfile.f
  time.sleep(2)
  # !rm /content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/trashfile.f
  time.sleep(2)
  clear_output()
  
#@markdown Or
Path_to_trained_model = "" #@param {type:"string"}
#@markdown Insert the full path of your trained model (eg: /content/gdrive/MyDrive/zarathustra.ckpt) and it will automatically be placed in the right place, otherwise, leave it EMPTY (make sure there are no spaces in the path)
if (Path_to_trained_model !=''):
  if os.path.exists(str(Path_to_trained_model)):
    clear_output()
    # !cp $Path_to_trained_model '/content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/model.ckpt'
    if os.path.exists('/content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/model.ckpt'):
      print('Model placed in the right directory')
    else:
      print('Something went wrong')
  else:
    print('Wrong path, use the colab file explorer to copy the path')

else:


  if token == "" and not os.path.exists('/content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/model.ckpt'):
    token=input("Insert your huggingface token :")
    # %cd /content/
    # !git init
    # !git lfs install --system --skip-repo
    # !git remote add -f origin "https://USER:{token}@huggingface.co/CompVis/stable-diffusion-v-1-4-original"
    # !git config core.sparsecheckout true
    # !echo "sd-v1-4.ckpt" > .git/info/sparse-checkout
    # !git pull origin main
    # !mv '/content/sd-v1-4.ckpt' '/content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/model.ckpt'
    if os.path.exists('/content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/model.ckpt'):
      clear_output()
      print("Model successfully downloaded")  

  elif not os.path.exists('/content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/model.ckpt'):
        # %cd /content/
        # !git init
        # !git lfs install --system --skip-repo
        # !git remote add -f origin "https://USER:{token}@huggingface.co/CompVis/stable-diffusion-v-1-4-original"
        # !git config core.sparsecheckout true
        # !echo "sd-v1-4.ckpt" > .git/info/sparse-checkout
        # !git pull origin main
        # !mv '/content/sd-v1-4.ckpt' '/content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/model.ckpt'
        if os.path.exists('/content/gdrive/MyDrive/stable-diffusion-webui/models/ldm/stable-diffusion-v1/model.ckpt'):
          clear_output()
          print("Model successfully downloaded")  
  else:
      print("Model already exists")

  if os.path.exists('/content/.git'):
    # !rm -r /content/.git

# %%
#@markdown # Installing Requirements
import os
from IPython.utils import capture

with capture.capture_output() as cap: 
  if not os.path.exists('/content/gdrive/MyDrive/stable-diffusion-webui/arial.ttf'):
    # !wget https://github.com/matomo-org/travis-scripts/blob/master/fonts/Arial.ttf?raw=true -O /content/gdrive/MyDrive/stable-diffusion-webui/arial.ttf
    # !sudo apt-get install fonts-dejavu
    # !sudo fc-cache

with capture.capture_output() as cap:     
  if not os.path.exists('/content/gdrive/MyDrive/stable-diffusion-webui/src/taming-transformers/taming'):
    # !mkdir /content/gdrive/MyDrive/stable-diffusion-webui/src
    # %cd /content/gdrive/MyDrive/stable-diffusion-webui/src
    # !git clone https://github.com/CompVis/taming-transformers
    # !cp -R /content/gdrive/MyDrive/stable-diffusion-webui/src/taming-transformers/taming /content/gdrive/MyDrive/stable-diffusion-webui/scripts
    # !git clone https://github.com/openai/CLIP
    # !mv /content/gdrive/MyDrive/stable-diffusion-webui/src/CLIP/ /content/gdrive/MyDrive/stable-diffusion-webui/src/clip
    # !mv /content/gdrive/MyDrive/stable-diffusion-webui/src/clip/clip /content/gdrive/MyDrive/stable-diffusion-webui/scripts
    # !git clone https://github.com/hlky/k-diffusion-sd
    # !mv /content/gdrive/MyDrive/stable-diffusion-webui/src/k-diffusion-sd /content/gdrive/MyDrive/stable-diffusion-webui/src/k-diffusion
    # !cp -R /content/gdrive/MyDrive/stable-diffusion-webui/src/k-diffusion/k_diffusion /content/gdrive/MyDrive/stable-diffusion-webui/scripts
    # !git clone  https://github.com/devilismyfriend/latent-diffusion
    # !cp -R /content/gdrive/MyDrive/stable-diffusion-webui/ldm /content/gdrive/MyDrive/stable-diffusion-webui/scripts/ldm
    # !cp -R /content/gdrive/MyDrive/stable-diffusion-webui/optimizedSD /content/gdrive/MyDrive/stable-diffusion-webui/scripts
   
with capture.capture_output() as cap:   
  # !cp -R /content/fast-stable-diffusion/Relaxed-mode/frontend /content/gdrive/MyDrive/stable-diffusion-webui/scripts


with capture.capture_output() as cap: 
  # %cd /content/
  # !wget https://github.com/TheLastBen/fast-stable-diffusion/raw/main/Dependencies/Dependencies_HLKY
  # !mv Dependencies_HLKY Dependencies_HLKY.7z
  !7z x Dependencies_HLKY.7z
  time.sleep(3)
  # !cp -r /content/usr/local/lib/python3.7/dist-packages /usr/local/lib/python3.7/
  # !rm -r /content/usr
  # !rm Dependencies_HLKY.7z
  # %cd /content/gdrive/MyDrive/stable-diffusion-webui/scripts/ldm/modules
  # !wget -O attention.py https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/precompiled/attention.py
  # !pip install -q gradio==3.3.1

# %%
#@markdown # Installing xformers
import os
import time
from IPython.display import HTML
from IPython.display import clear_output
from subprocess import getoutput

s = getoutput('nvidia-smi')
if 'T4' in s:
  gpu = 'T4'
elif 'P100' in s:
  gpu = 'P100'
elif 'V100' in s:
  gpu = 'V100'
elif 'A100' in s:
  gpu = 'A100'

while True:
    try: 
        gpu=='T4'or gpu=='P100'or gpu=='V100'or gpu=='A100'
        break
    except:
        pass
    print('it seems that your GPU is not supported at the moment')
    time.sleep(5)

if (gpu=='T4'):
  # %pip install https://github.com/TheLastBen/fast-stable-diffusion/raw/main/precompiled/T4/xformers-0.0.13.dev0-py3-none-any.whl
  
elif (gpu=='P100'):
  # %pip install https://github.com/TheLastBen/fast-stable-diffusion/raw/main/precompiled/P100/xformers-0.0.13.dev0-py3-none-any.whl

elif (gpu=='V100'):
  # %pip install https://github.com/TheLastBen/fast-stable-diffusion/raw/main/precompiled/V100/xformers-0.0.13.dev0-py3-none-any.whl

elif (gpu=='A100'):
  # %pip install https://github.com/TheLastBen/fast-stable-diffusion/raw/main/precompiled/A100/xformers-0.0.13.dev0-py3-none-any.whl  

clear_output()
print('DONE !')

# %%
#@markdown # Start stable-diffusion
from IPython.utils import capture
from subprocess import getoutput
import os
import time

with capture.capture_output() as cap: 
  if not os.path.exists('/tools/node/bin/lt'):
    # !npm install -g localtunnel

Use_Gradio_Server = False #@param {type:"boolean"}
#@markdown  - Only if you have trouble connecting to the local server

with capture.capture_output() as cap: 
  # %cd /content

share=''
if Use_Gradio_Server:
  share='--share'
  # !sed -i '1048s@.*@            self.server_name = server_name@' /usr/local/lib/python3.7/dist-packages/gradio/blocks.py
  # !sed -i '1050s@.*@            self.server_port = server_port@' /usr/local/lib/python3.7/dist-packages/gradio/blocks.py  
  # !sed -i '1054s@.*@            self.protocol = "https" if self.local_url.startswith("https") else "http"@' /usr/local/lib/python3.7/dist-packages/gradio/blocks.py  

else:
  share=''

  # !nohup lt --port 7860 > srv.txt 2>&1 &
  time.sleep(2)
  # !grep -o 'https[^ ]*' /content/srv.txt >srvr.txt
  time.sleep(2)
  srv= getoutput('cat /content/srvr.txt')

  # !sed -i '1048s@.*@            self.server_name = "{srv[8:]}"@' /usr/local/lib/python3.7/dist-packages/gradio/blocks.py
  # !sed -i '1050s@.*@            self.server_port = 443@' /usr/local/lib/python3.7/dist-packages/gradio/blocks.py
  # !sed -i '1054s@.*@            self.protocol = "https"@' /usr/local/lib/python3.7/dist-packages/gradio/blocks.py  
          
  # !sed -i '13s@.*@    "PUBLIC_SHARE_TRUE": "[32mConnected",@' /usr/local/lib/python3.7/dist-packages/gradio/strings.py
  
  # !rm /content/srv.txt
  # !rm /content/srvr.txt

with capture.capture_output() as cap: 
  # %cd /content/gdrive/MyDrive/stable-diffusion-webui/

# !python /content/gdrive/MyDrive/stable-diffusion-webui/scripts/Relaxed.py $share
